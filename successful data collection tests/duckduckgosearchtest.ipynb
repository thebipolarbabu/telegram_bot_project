# %% [markdown]
# SUCCESS!!!!!

# %%
# !pip install ddgs
# !pip install httpx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ddgs in c:\users\faman\appdata\roaming\python\python313\site-packages (9.10.0)
# Requirement already satisfied: click>=8.1.8 in c:\programdata\anaconda3\lib\site-packages (from ddgs) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in c:\users\faman\appdata\roaming\python\python313\site-packages (from ddgs) (1.0.0)
# Requirement already satisfied: lxml>=4.9.4 in c:\programdata\anaconda3\lib\site-packages (from ddgs) (5.3.0)
# Requirement already satisfied: httpx>=0.28.1 in c:\programdata\anaconda3\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in c:\users\faman\appdata\roaming\python\python313\site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in c:\users\faman\appdata\roaming\python\python313\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\faman\appdata\roaming\python\python313\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in c:\users\faman\appdata\roaming\python\python313\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\faman\appdata\roaming\python\python313\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\faman\appdata\roaming\python\python313\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: httpx in c:\programdata\anaconda3\lib\site-packages (0.28.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting newspaper3k
#   Using cached newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (4.13.5)
# Requirement already satisfied: Pillow>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (12.0.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (6.0.3)
# Requirement already satisfied: cssselect>=0.9.2 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: nltk>=3.2.1 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (3.9.2)
# Requirement already satisfied: requests>=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (2.32.5)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tldextract>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (5.1.2)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Using cached feedfinder2-0.0.4-py3-none-any.whl
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Using cached jieba3k-0.35.1-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\programdata\anaconda3\lib\site-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Using cached tinysegmenter-0.3-py3-none-any.whl
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.15.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2026.1.4)
# Requirement already satisfied: requests-file>=1.4 in c:\programdata\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\programdata\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.20.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Using cached feedparser-6.0.12-py3-none-any.whl (81 kB)
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, feedfinder2, newspaper3k
#
#    ------------- -------------------------- 2/6 [jieba3k]
#    ------------- -------------------------- 2/6 [jieba3k]
#    ------------- -------------------------- 2/6 [jieba3k]
#    ------------- -------------------------- 2/6 [jieba3k]
#    -------------------- ------------------- 3/6 [feedparser]
#    -------------------------- ------------- 4/6 [feedfinder2]
#    --------------------------------- ------ 5/6 [newspaper3k]
#    ---------------------------------------- 6/6 [newspaper3k]
#
# Successfully installed feedfinder2-0.0.4 feedparser-6.0.12 jieba3k-0.35.1 newspaper3k-0.2.8 sgmllib3k-1.0.0 tinysegmenter-0.3
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lxml_html_clean
#   Using cached lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from lxml_html_clean) (5.3.0)
# Using cached lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.4.3

# %% [markdown]
# Region params:
#
# xa-ar for Arabia
# xa-en for Arabia (en)
# ar-es for Argentina
# au-en for Australia
# at-de for Austria
# be-fr for Belgium (fr)
# be-nl for Belgium (nl)
# br-pt for Brazil
# bg-bg for Bulgaria
# ca-en for Canada
# ca-fr for Canada (fr)
# ct-ca for Catalan
# cl-es for Chile
# cn-zh for China
# co-es for Colombia
# hr-hr for Croatia
# cz-cs for Czech Republic
# dk-da for Denmark
# ee-et for Estonia
# fi-fi for Finland
# fr-fr for France
# de-de for Germany
# gr-el for Greece
# hk-tzh for Hong Kong
# hu-hu for Hungary
# in-en for India
# id-id for Indonesia
# id-en for Indonesia (en)
# ie-en for Ireland
# il-he for Israel
# it-it for Italy
# jp-jp for Japan
# kr-kr for Korea
# lv-lv for Latvia
# lt-lt for Lithuania
# xl-es for Latin America
# my-ms for Malaysia
# my-en for Malaysia (en)
# mx-es for Mexico
# nl-nl for Netherlands
# nz-en for New Zealand
# no-no for Norway
# pe-es for Peru
# ph-en for Philippines
# ph-tl for Philippines (tl)
# pl-pl for Poland
# pt-pt for Portugal
# ro-ro for Romania
# ru-ru for Russia
# sg-en for Singapore
# sk-sk for Slovak Republic
# sl-sl for Slovenia
# za-en for South Africa
# es-es for Spain
# se-sv for Sweden
# ch-de for Switzerland (de)
# ch-fr for Switzerland (fr)
# ch-it for Switzerland (it)
# tw-tzh for Taiwan
# th-th for Thailand
# tr-tr for Turkey
# ua-uk for Ukraine
# uk-en for United Kingdom
# us-en for United States
# ue-es for United States (es)
# ve-es for Venezuela
# vn-vi for Vietnam
# wt-wt for No region

# %% [markdown]
# DuckDuckGo text search generator. Query params: https://duckduckgo.com/params.
#
#     Args:
#         keywords: keywords for query.
#         region: us-en, uk-en, ru-ru, etc. Defaults to None.
#         safesearch: on, moderate, off. Defaults to "moderate".
#         timelimit: d, w, m, y. Defaults to None.
#         backend: auto, html, lite. Defaults to auto.
#             auto - try all backends in random order,
#             html - collect data from https://html.duckduckgo.com,
#             lite - collect data from https://lite.duckduckgo.com,
#             bing - collect data from https://www.bing.com.
#         max_results: max number of results. If None, returns results only from the first response. Defaults to None.
#
#     Returns:
#         List of dictionaries with search results.

# %% [markdown]
# duckduckgo gives links, headlines, subtitles

# %%
import pandas as pd
from ddgs import DDGS
results = DDGS().text(query="galgotias impact ai summit", region="in-en",safesearch= "off", timelimit="7d", max_results=30)
df=pd.DataFrame(results)
#df.to_csv("C:/Users/faman/Downloads/ddgs_results.csv", index=False)
df
# Out:
#                                                 title  \
# 0   Google News - AI Impact Summit 2026 in India -...
# 1   ‘She was not authorised to …’: Galgotias Unive...
# 2   Galgotias University leaves AI Summit with rob...
# 3   Rahul Gandhi slams AI Summit over Galgotias ro...
# 4   Moving past Galgotias row, desi tech emerges r...
# 5   ‘We Do Not Want Any Controversy’: IT Ministry ...
# 6   Trouble doubles for Galgotias : After robodog....
# 7   "Misinformation Can't Be Encouraged": Centre O...
# 8   Indian university kicked out of summit for fal...
# 9   Galgotias University ने देसी बताकर पेश कर दिया...
# 10  Video Summary - China Mocks India over Al Summ...
