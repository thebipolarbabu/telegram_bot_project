# %% [markdown]
# Failed attempt 2 - data in json format, hard to work with, irrelavent articles

# %% [markdown]
# Mediastack api testing

# %%
import http.client, urllib.parse
#import pandas as pd

# %%
conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'api key here',
    'categories': '-politics',
    'sort': 'published_desc',
    'limit': 10,
    'languages': 'en'
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()



#df=pd.read_json(data.decode('utf-8'))
#df.head()

# %%
data.decode('utf-8')
# Out:
# '{"pagination":{"limit":10,"offset":0,"count":10,"total":10000},"data":[{"author":null,"title":"Keve joins Sofia summit to drive green business innovation","description":"The Cyprus Chamber of Commerce and Industry (Keve) joined European partners in Sofia, Bulgaria, on February 19 and February 20, to coordinate the next stages of the SUSTAINET green business initiative. The SUSTAINET project, co-funded by the European Union under the Erasmus+ programme, provides tools to improve environmental performance while promoting knowledge sharing through a [\\u0026#8230;]","url":"https:\\/\\/cyprus-mail.com\\/2026\\/02\\/20\\/keve-joins-sofia-summit-to-drive-green-business-innovation","source":"cyprus-mail","image":"https:\\/\\/cyprus-mail.com\\/image\\/s640x\\/file\\/wp-content\\/uploads\\/2026\\/02\\/SustaiNet-pic.jpeg","category":"general","language":"en","country":"us","published_at":"2026-02-20T11:07:55+00:00"},{"author":null,"title":"Rich fare dodgers caught on camera should have shaming footage released to the public say train firms after former banker dodged \\u00a35,900 tickets","description":"The call comes as former HSBC executive Joseph Molloy was handed a fine and suspended sentence at Inner London Crown Court for employing a ticketing scam to dodge nearly \\u00a36,000 in rail fares.","url":"https:\\/\\/www.dailymail.co.uk\\/news\\/article-15576985\\/Rich-fare-dodgers-shaming-footage-train-banker.html?ns_mchannel=rss\\u0026ns_campaign=1490\\u0026ito=1490","source":"Mail","image":"https:\\/\\/i.dailymail.co.uk\\/1s\\/2026\\/02\\/20\\/10\\/106541209-0-image-a-2_1771584459011.jpg","category":"general","language":"en","country":"gb","published_at":"2026-02-20T11:07:47+00:00"},{"author":"ABMN Staff","title":"Alignment Healthcare (NASDAQ:ALHC) President Sells $618,900.00 in Stock","description":"Alignment Healthcare (NASDAQ:ALHC) President Sells $618,900.00 in Stock","url":"https:\\/\\/www.americanbankingnews.com\\/2026\\/02\\/20\\/alignment-healthcare-nasdaqalhc-president-sells-618900-00-in-stock.html","source":"americanbankingnews","image":null,"category":"general","language":"en","country":"us","published_at":"2026-02-20T11:07:36+00:00"},{"author":"Ellie White-Stevens","title":"Fayetteville Positions for Growth at Economic Summit","description":"Over the next several weeks, The Citizen will break down how each incorporated city and town in Fayette County plans to grow, build, and compete in a rapidly changing regional [\\u0026#8230;]","url":"https:\\/\\/thecitizen.com\\/2026\\/02\\/20\\/fayetteville-positions-for-growth-at-economic-summit\\/","source":"thecitizen","image":null,"category":"general","language":"en","country":"us","published_at":"2026-02-20T11:07:32+00:00"},{"author":null,"title":"Pictured: Boy, 17, and girl, 15, who were found dead at holiday park - as man, 33, is arrested in connection with their deaths","description":"Ethan Slater , 17, and Cherish Bean, 15, were staying at Little Eden Holiday Park in Bridlington during the half-term holidays when they were found dead on Wednesday.","url":"https:\\/\\/www.dailymail.co.uk\\/news\\/article-15577093\\/Tributes-paid-beautiful-boy-17-girl-15-dead-holiday-park-man-33-arrested-connection-deaths.html?ns_mchannel=rss\\u0026ito=1490\\u0026ns_campaign=1490","source":"dailymail","image":"https:\\/\\/i.dailymail.co.uk\\/1s\\/2026\\/02\\/20\\/10\\/106541203-0-image-m-49_1771584449541.jpg","category":"general","language":"en","country":"us","published_at":"2026-02-20T11:07:31+00:00"},{"author":"Rohini Bhattacharya","title":"Best Real cash Web based Lucky Wizard Rtp $1 deposit casinos to possess 2026","description":"Getting started during the a bona fide currency online casino is quick and you can easy\\u2014even though you\\u2019re a beginner. Their headings tend to be classic dining table online game\\u0026#8230;","url":"https:\\/\\/www.apunkachoice.com\\/best-real-cash-web-based-lucky-wizard-rtp-1-deposit-casinos-to-possess-2026\\/","source":"apunkachoice","image":null,"c ...
