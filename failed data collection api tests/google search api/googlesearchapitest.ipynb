# %% [markdown]
# Failed attempt - 3

# %%
#!pip install httpx pandas

# %%
import os
import httpx
import requests
import pandas as pd
url = "https://www.googleapis.com/customsearch/v1"
params={
    "key": "api key here",
    "cx": "search engine id here",
    "q": "query here"
    }
#response = requests.get(url,params=params)
#items=response.json().get("items", [])
#print(items)

response = httpx.get(url, params=params)
response.raise_for_status()  # Check if the request was successful
items = response.json().get("items", [])
print(items)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[1], line 16
#      11 #response = requests.get(url,params=params)
#      12 #items=response.json().get("items", [])
#      13 #print(items)
#      15 response = httpx.get(url, params=params)
# ---> 16 response.raise_for_status()  # Check if the request was successful
#      17 items = response.json().get("items", [])
#      18 print(items)
#
# File c:\Users\faman\.conda\envs\qc\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://www.googleapis.com/customsearch/v1?key=api+key+here&cx=search+engine+id+here&q=query+here'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
