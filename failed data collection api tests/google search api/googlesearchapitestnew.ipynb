# %% [markdown]
# Failed attempt 4

# %%
# !pip install google-api-python-client
# !pip install google-auth
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.190.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Downloading httplib2-0.31.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.3.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.30.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.27.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\programdata\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.3)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\programdata\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.23)
# Downloading google_api_python_client-2.190.0-py3-none-any.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.7 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.7 MB 3.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/14.7 MB 4.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.9/14.7 MB 5.7 MB/s eta 0:00:02
#    --------------- ------------------------ 5.8/14.7 MB 6.2 MB/s eta 0:00:02
#    ------------------- -------------------- 7.3/14.7 MB 6.5 MB/s eta 0:00:02
#    ------------------------ --------------- 8.9/14.7 MB 6.6 MB/s eta 0:00:01
#    --------------------------- ------------ 10.2/14.7 MB 6.6 MB/s eta 0:00:01
#    ------------------------------ --------- 11.3/14.7 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.7 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 3.8 MB/s  0:00:03
# Downloading google_api_core-2.30.0-py3-none-any.whl (173 kB)
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
# Downloading google_auth_httplib2-0.3.0-py3-none-any.whl (9.5 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
# Downloading proto_plus-1.27.1-py3-none-any.whl (50 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Installing collected packages: uritemplate, rsa, proto-plus, httplib2, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
#
#    ---- ----------------------------------- 1/9 [rsa]
#    -------- ------------------------------- 2/9 [proto-plus]
#    ------------- -------------------------- 3/9 [httplib2]
#    ----------------- ---------------------- 4/9 [googleapis-common-protos]
#    ----------------- ---------------------- 4/9 [googleapis-common-protos]
#    ----------------- ---------------------- 4/9 [googleapis-common-protos]
#    ----------------- ---------------------- 4/9 [googleapis-common-protos]
#    ----------------- ---------------------- 4/9 [googleapis-common-protos]
#    ---------------------- ----------------- 5/9 [google-auth]
#    ---------------------- ----------------- 5/9 [google-auth]
#    ---------------------- ----------------- 5/9 [google-auth]
#    ---------------------- ----------------- 5/9 [google-auth]
#    ---------------------- ----------------- 5/9 [google-auth]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ------------------------------- -------- 7/9 [google-api-core]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ----------------------------------- ---- 8/9 [google-api-python-client]
#    ---------------------------------------- 9/9 [google-api-python-client]
#
# Successfully installed google-api-core-2.30.0 google-api-python-client-2.190.0 google-auth-2.48.0 google-auth-httplib2-0.3.0 googleapis-common-protos-1.72.0 httplib2-0.31.2 proto-plus-1.27.1 rsa-4.9.1 uritemplate-4.2.0
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\faman\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-auth in c:\users\faman\appdata\roaming\python\python313\site-packages (2.48.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\programdata\anaconda3\lib\site-packages (from google-auth) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\faman\appdata\roaming\python\python313\site-packages (from google-auth) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth) (2.0.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth) (2.23)

# %%
API_KEY = 'api key here'
SEARCH_ENGINE_ID = 'search engine id here'
from googleapiclient.discovery import build
def google_search(query, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=API_KEY)
    results = service.cse().list(q=query, cx=SEARCH_ENGINE_ID, **kwargs).execute()
    return results['items']
query = "Python programming"
results = google_search(query, API_KEY, SEARCH_ENGINE_ID, num=5)
for result in results:    
    print(result['title'])
    print(result['link'])
    print(result['snippet'])
    print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 API_KEY = 'api key here'
#       2 SEARCH_ENGINE_ID = 'search engine id here'
# ----> 3 from googleapiclient.discovery import build
#       4 def google_search(query, api_key, cse_id, **kwargs):
#       5     service = build("customsearch", "v1", developerKey=API_KEY)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\googleapiclient\discovery.py:45
#      43 from google.auth.exceptions import MutualTLSChannelError
#      44 from google.auth.transport import mtls
# ---> 45 from google.oauth2 import service_account
#      47 # Third-party imports
#      48 import httplib2
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\oauth2\service_account.py:78
#      76 from google.auth import _constants
#      77 from google.auth import _helpers
# ---> 78 from google.auth import _service_account_info
#      79 from google.auth import credentials
#      80 from google.auth import exceptions
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\auth\_service_account_info.py:20
#      17 import io
#      18 import json
# ---> 20 from google.auth import crypt
#      21 from google.auth import exceptions
#      24 def from_dict(data, require=None, use_rsa_signer=True):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\auth\crypt\__init__.py:41
#      15 """Cryptography helpers for verifying and signing messages.
#      16
#      17 The simplest way to verify signatures is using :func:`verify_signature`::
#    (...)     37 version is at least 1.4.0.
#      38 """
#      40 from google.auth.crypt import base
# ---> 41 from google.auth.crypt import es
#      42 from google.auth.crypt import es256
#      43 from google.auth.crypt import rsa
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\auth\crypt\es.py:21
#      18 from dataclasses import dataclass
#      19 from typing import Any, Dict, Optional, Union
# ---> 21 import cryptography.exceptions
#      22 from cryptography.hazmat import backends
#      23 from cryptography.hazmat.primitives import hashes
#
# ModuleNotFoundError: No module named 'cryptography'
